# %%
# Named Entity Recognition

# %%
import spacy
import pandas as pd
import nltk
nltk.download('punkt')
nltk.download('averaged_perceptron_tagger')
nltk.download('maxent_ne_chunker')
nltk.download('words')
# Out:
# [nltk_data] Downloading package punkt to
# [nltk_data]     C:\Users\LENOVO\AppData\Roaming\nltk_data...
# [nltk_data]   Package punkt is already up-to-date!
# [nltk_data] Downloading package averaged_perceptron_tagger to
# [nltk_data]     C:\Users\LENOVO\AppData\Roaming\nltk_data...
# [nltk_data]   Package averaged_perceptron_tagger is already up-to-
# [nltk_data]       date!
# [nltk_data] Downloading package maxent_ne_chunker to
# [nltk_data]     C:\Users\LENOVO\AppData\Roaming\nltk_data...
# [nltk_data]   Package maxent_ne_chunker is already up-to-date!
# [nltk_data] Downloading package words to
# [nltk_data]     C:\Users\LENOVO\AppData\Roaming\nltk_data...
# [nltk_data]   Package words is already up-to-date!
# True

# %%
df1 = pd.DataFrame(columns = ['Text', 'pos'])
df2 = pd.DataFrame(columns = ['Text', 'Label'])

# %%
def annotate1(text):
    nlp = spacy.load("en_core_web_sm")
    doc = nlp(text)

    rows = []
    for token in doc:
        print(token.text, token.pos_)
        rows.append([token.text, token.pos_])
    df1 = pd.DataFrame(rows, columns=['Text', 'pos'])
    #df.to_csv('C:\Users\LENOVO\Desktop\cours\S5\Ingénierie cognitive\Projet\data.csv')
    return df1

# %%
def annotate2(text):
    nlp = spacy.load("en_core_web_sm")
    doc = nlp(text)

    rows = []
    for ent in doc.ents:
        print(ent.text, ent.label_)
        rows.append([ent.text, ent.label_])
    df2 = pd.DataFrame(rows, columns=['Text', 'label'])
    #df.to_csv(r'C:\Users\LENOVO\Desktop\cours\S5\Ingénierie cognitive\Projet\data2.csv')
    return df2

# %%
f = open(r'C:\Users\LENOVO\Desktop\cours\S5\Ingénierie cognitive\livrable2\Article1_text.txt', 'r',encoding="utf8")
txt = f.read()

# %%
annotate1(txt)
# Out:
# Malaria PROPN
# and CCONJ
# COVID-19 NOUN
# may AUX
# have VERB
# similar ADJ
# aspects NOUN
# and CCONJ
# seem VERB
# to PART
# have VERB
# a DET
# strong ADJ
#
#  SPACE
# potential NOUN
# for ADP
# mutual ADJ
# influence NOUN
# . PUNCT
# They PRON
# have AUX
# already ADV
# caused VERB
# millions NOUN
# of ADP
# deaths NOUN
# , PUNCT
#
#  SPACE
# and CCONJ
# the DET
# regions NOUN
# where ADV
# malaria NOUN
# is VERB
# endemic ADJ
# regions NOUN
# are VERB
# at ADP
# risk NOUN
# of ADP
# suffering VERB
# from ADP
#
#  SPACE
# the DET
# consequences NOUN
# of ADP
# COVID-19 NOUN
# due ADP
# to ADP
# mutual ADJ
# side NOUN
# effects NOUN
# , PUNCT
# such ADJ
# as ADP
# less ADJ
# access NOUN
#
#  SPACE
# to ADP
# treatment NOUN
# for ADP
# patients NOUN
# with ADP
# malaria NOUN
# due ADP
# to ADP
# the DET
# fear NOUN
# of ADP
# access NOUN
# to ADP
# healthcare NOUN
#
#  SPACE
# centers NOUN
# leading VERB
# to ADP
# worse ADJ
# outcomes NOUN
# and CCONJ
# diagnostic ADJ
# delays NOUN
# . PUNCT
#
#   SPACE
# Moreover ADV
# , PUNCT
# the DET
# similar ADJ
# and CCONJ
# generic ADJ
# symptoms NOUN
# make VERB
# it PRON
# harder ADJ
# to PART
# achieve VERB
# an DET
#
#  SPACE
# immediate ADJ
# diagnosis NOUN
# . PUNCT
# Healthcare NOUN
# systems NOUN
# and CCONJ
# professionals NOUN
# will AUX
# face VERB
# a DET
# great ADJ
#
#  SPACE
# challenge NOUN
# in ADP
# case NOUN
# of ADP
# a DET
# syndemic NOUN
# . PUNCT
# Here ADV
# , PUNCT
# we PRON
# present VERB
# an DET
# overview NOUN
# of ADP
# common ADJ
# and CCONJ
#
#  SPACE
# different ADJ
# findings NOUN
# for ADP
# both DET
# diseases NOUN
# with ADP
# possible ADJ
# mutual ADJ
# influences NOUN
# of ADP
# one NUM
# on ADP
#
#  SPACE
# the DET
# other ADJ
# , PUNCT
# especially ADV
# in ADP
# countries NOUN
# with ADP
# limited ADJ
# resources NOUN
# . PUNCT
# The DET
# role NOUN
# of ADP
# young ADJ
#
#  SPACE
# health NOUN
# professionals NOUN
# , PUNCT
# well ADV
# - PUNCT
# motivated VERB
# and CCONJ
# trained VERB
# in ADP
# primary ADJ
# care NOUN
# , PUNCT
# will AUX
# also ADV
# be VERB
#
#  SPACE
# essential ADJ
# in ADP
# countries NOUN
# with ADP
# a DET
# high ADJ
# burden NOUN
# of ADP
# malaria NOUN
# . PUNCT
# In ADP
# patients NOUN
# with ADP
# symptoms NOUN
#
#  SPACE
# such ADJ
# as ADP
# fever NOUN
# , PUNCT
# fatigue NOUN
# , PUNCT
# and CCONJ
# headache NOUN
# , PUNCT
# both CCONJ
# malaria NOUN
# and CCONJ
# COVID-19 NOUN
# tests NOUN
# should AUX
#
#  SPACE
# always ADV
# be AUX
# performed VERB
# . PUNCT
# According VERB
# to ADP
# recent ADJ
# WHO PRON
# recommendations VERB
# , PUNCT
# in ADP
# the DET
# case NOUN
#
#  SPACE
# of ADP
# challenges NOUN
# due ADJ
# to ADP
# the DET
# COVID-19 NOUN
# pandemic ADJ
# ( PUNCT
# e.g. ADV
# , PUNCT
# supply NOUN
# chain NOUN
# disruption NOUN
# for ADP
#
#  SPACE
# RDTs PROPN
# , PUNCT
# health NOUN
# worker NOUN
# absenteeism NOUN
# , PUNCT
# shortage NOUN
# of ADP
# personal ADJ
# protective ADJ
# equipment NOUN
# ) PUNCT
#
#  SPACE
# a DET
# malaria ADJ
# diagnosis NOUN
# should AUX
# be AUX
# considered VERB
# for ADP
# all DET
# fever NOUN
# cases NOUN
# in ADP
# endemic ADJ
#
#  SPACE
# countries NOUN
# . PUNCT
# On ADP
# the DET
# other ADJ
# hand NOUN
# , PUNCT
# patients NOUN
# with ADP
# COVID-19 NOUN
# - PUNCT
# related VERB
# symptoms NOUN
# that DET
#
#  SPACE
# negative ADJ
# for ADP
# malaria NOUN
# must AUX
# undergo VERB
# isolation NOUN
# to PART
# exclude VERB
# COVID-19 NOUN
# until ADP
#
#  SPACE
# repetition NOUN
# of ADP
# the DET
# virological ADJ
# sample NOUN
# , PUNCT
# thus ADV
# reducing VERB
# the DET
# potential ADJ
# risk NOUN
# of ADP
#
#  SPACE
# transmission NOUN
# . PUNCT
# Even ADV
# though SCONJ
# a DET
# COVID-19 NOUN
# outbreak NOUN
# may AUX
# not PART
# occur VERB
# in ADP
# the DET
# malariaendemic ADJ
# regions NOUN
# , PUNCT
# the DET
# WHO PRON
# has AUX
# called VERB
# for ADP
# ministries NOUN
# of ADP
# health NOUN
# and CCONJ
# national ADJ
#
#  SPACE
# malaria NOUN
# control NOUN
# programs NOUN
# to PART
# ensure VERB
# that SCONJ
# malaria NOUN
# control NOUN
# efforts NOUN
# are AUX
# not PART
#
#  SPACE
# disrupted VERB
# while SCONJ
# facing VERB
# the DET
# COVID-19 NOUN
# response NOUN
# . PUNCT
# Preparedness NOUN
# is AUX
# the DET
# key NOUN
# to ADP
#
#  SPACE
# tackling VERB
# any DET
# public ADJ
# health NOUN
# crisis NOUN
# , PUNCT
# and CCONJ
# malaria NOUN
# - PUNCT
# endemic ADJ
# countries NOUN
# need VERB
# to PART
# be VERB
#
#  SPACE
# prepared VERB
# for ADP
# the DET
# challenges NOUN
# COVID-19 X
# could AUX
# pose VERB
# . PUNCT
#
#   SPACE
# The DET
# impact NOUN
# of ADP
# the DET
# epidemic NOUN
# on ADP
# the DET
# health NOUN
# financing NOUN
# system NOUN
# as ADP
# a DET
# whole NOUN
# is AUX
#
#  SPACE
# considered VERB
# . PUNCT
# A DET
# polarization NOUN
# of ADP
# economic ADJ
# resources NOUN
# happened VERB
# with ADP
# Ebola PROPN
# , PUNCT
# and CCONJ
# this DET
#
#  SPACE
# is AUX
# also ADV
# being AUX
# observed VERB
# with ADP
# COVID-19 NOUN
# . PUNCT
# Therefore ADV
# , PUNCT
# in ADP
# the DET
# next ADJ
# month NOUN
# , PUNCT
# it PRON
# could AUX
#
#  SPACE
# be VERB
# possible ADJ
# to PART
# observe VERB
# an DET
# important ADJ
# decrease NOUN
# in ADP
# economic ADJ
# and CCONJ
# human ADJ
#
#  SPACE
# resources NOUN
# for ADP
# malaria NOUN
# control NOUN
# programs NOUN
# , PUNCT
# with ADP
# a DET
# real ADJ
# risk NOUN
# of ADP
# reducing VERB
# prevention NOUN
# . PUNCT
#
#  SPACE
# This DET
# is VERB
# turn NOUN
# may AUX
# result VERB
# in ADP
# an DET
# increase NOUN
# in ADP
# the DET
# numbers NOUN
# of ADP
# cases NOUN
# , PUNCT
# with ADP
# a DET
#
#  SPACE
# consequent ADJ
# increase NOUN
# in ADP
# morbidity NOUN
# and CCONJ
# mortality NOUN
# . PUNCT
# The DET
# characteristics NOUN
# of ADP
# COVID19 PROPN
# and CCONJ
# the DET
# previous ADJ
# experiences NOUN
# of ADP
# the DET
# Ebola PROPN
# epidemic NOUN
# indicate VERB
# the DET
# need NOUN
# for ADP
#
#  SPACE
# malaria ADJ
# - PUNCT
# endemic ADJ
# countries NOUN
# to PART
# consider VERB
# measures NOUN
# for ADP
# preparation NOUN
# and CCONJ
#
#  SPACE
# prevention NOUN
# , PUNCT
# focusing VERB
# on ADP
# not PART
# only ADV
# the DET
# threat NOUN
# of ADP
# COVID-19 NOUN
# but CCONJ
# also ADV
# the DET
# possible ADJ
#
#  SPACE
# impact NOUN
# of ADP
# other ADJ
# diseases NOUN
# , PUNCT
# especially ADV
# malaria NOUN
# [ PUNCT
# 16 NUM
# ] PUNCT
# . PUNCT
# In ADP
# order NOUN
# to PART
# face VERB
# these DET
# possible ADJ
#
#  SPACE
# scenarios NOUN
# , PUNCT
# COVID-19 NOUN
# preparedness NOUN
# and CCONJ
# response NOUN
# in ADP
# malaria NOUN
# - PUNCT
# endemic ADJ
# countries NOUN
#
#  SPACE
# should AUX
# be AUX
# focused VERB
# on ADP
# the DET
# following VERB
# : PUNCT
# 1 X
# . PUNCT
# Local ADJ
# staff NOUN
# management NOUN
# , PUNCT
# including VERB
#
#  SPACE
# protection NOUN
# , PUNCT
# training NOUN
# , PUNCT
# supervision NOUN
# , PUNCT
# incentives NOUN
# , PUNCT
# and CCONJ
# rest NOUN
# shifts NOUN
# , PUNCT
# should AUX
# focus VERB
# on ADP
# all DET
#
#  SPACE
# factors NOUN
# that DET
# together ADV
# can AUX
# help VERB
# to PART
# ease VERB
# the DET
# fear NOUN
# of ADP
# contagion NOUN
# , PUNCT
# diminish VERB
# the DET
# anger NOUN
#
#  SPACE
# over ADP
# the DET
# death NOUN
# of ADP
# colleagues NOUN
# , PUNCT
# and CCONJ
# contain VERB
# strikes NOUN
# and CCONJ
# protests NOUN
# ; PUNCT
# 2 X
# . PUNCT
# Infection NOUN
#
#  SPACE
# prevention NOUN
# and CCONJ
# control NOUN
# measures NOUN
# should AUX
# be AUX
# applied VERB
# for ADP
# healthcare NOUN
# workers NOUN
# at ADP
#
#  SPACE
# the DET
# hospital NOUN
# and CCONJ
# peripheral ADJ
# levels NOUN
# , PUNCT
# making VERB
# sure ADJ
# to PART
# institute VERB
# appropriate ADJ
# lowtechnology NOUN
# measures NOUN
# such ADJ
# as ADP
# washing VERB
# hands NOUN
# with ADP
# sodium NOUN
# hypochlorite NOUN
# , PUNCT
#
#  SPACE
# segregation NOUN
# of ADP
# hospital NOUN
# waste NOUN
# , PUNCT
# and CCONJ
# proper ADJ
# application NOUN
# of ADP
# the DET
# personal ADJ
#
#  SPACE
# protective ADJ
# equipment NOUN
# ; PUNCT
# 3 X
# . PUNCT
# Community NOUN
# engagement NOUN
# is AUX
# crucial ADJ
# , PUNCT
# as ADP
# an DET
# effective ADJ
#
#  SPACE
# communication NOUN
# campaign NOUN
# involving VERB
# local ADJ
# leaders NOUN
# , PUNCT
# indigenous ADJ
# associations NOUN
# , PUNCT
# and CCONJ
#
#  SPACE
# media NOUN
# can AUX
# compel VERB
# the DET
# community NOUN
# to PART
# conform VERB
# to ADP
# the DET
# new ADJ
# behaviors NOUN
# ( PUNCT
# distancing NOUN
# , PUNCT
#
#  SPACE
# hand NOUN
# washing NOUN
# , PUNCT
# stopping VERB
# of ADP
# traditional ADJ
# funeral NOUN
# rites NOUN
# , PUNCT
# collaborating VERB
# in ADP
# contact NOUN
#
#  SPACE
# tracing NOUN
# , PUNCT
# etc X
# . PUNCT
# ) PUNCT
# and CCONJ
# therefore ADV
# in ADP
# the DET
# end NOUN
# be VERB
# able ADJ
# to PART
# retain VERB
# trust NOUN
# in ADP
# healthcare NOUN
#
#  SPACE
# structures NOUN
# and CCONJ
# operators NOUN
# ; PUNCT
# 4 X
# . PUNCT
# Data NOUN
# management NOUN
# and CCONJ
# operational ADJ
# research NOUN
#
#  SPACE
# should AUX
# not PART
# be AUX
# neglected VERB
# . PUNCT
# It PRON
# is AUX
# of ADP
# fundamental ADJ
# importance NOUN
# to PART
# monitor VERB
# trends NOUN
# of ADP
#
#  SPACE
# routine ADJ
# health NOUN
# services NOUN
# use NOUN
# , PUNCT
# maternal ADJ
# child NOUN
# health NOUN
# , PUNCT
# TB PROPN
# , PUNCT
# HIV PROPN
# , PUNCT
# etc X
# . PUNCT
#
#   SPACE
# Finally ADV
# , PUNCT
# from ADP
# a DET
# global ADJ
# perspective NOUN
# , PUNCT
# it PRON
# is AUX
# necessary ADJ
# to PART
# increase VERB
# and CCONJ
# join VERB
# efforts NOUN
#
#  SPACE
# in ADP
# order NOUN
# to PART
# develop VERB
# an DET
# effective ADJ
# vaccine NOUN
# and CCONJ
# it PRON
# make VERB
# available ADJ
# for ADP
# everyone PRON
# , PUNCT
# as ADP
#
#  SPACE
# this DET
# would AUX
# be VERB
# the DET
# most ADV
# effective ADJ
# preventive ADJ
# measure NOUN
# for ADP
# both DET
# disease NOUN
#            Text    pos
# 0       Malaria  PROPN
# 1           and  CCONJ
# 2      COVID-19   NOUN
# 3           may    AUX
# 4          have   VERB
# ..          ...    ...
# 802  preventive    ADJ
# 803     measure   NOUN
# 804         for    ADP
# 805        both    DET
# 806     disease   NOUN
#
# [807 rows x 2 columns]

# %%
annotate2(txt)
# Out:
# Malaria GPE
# COVID-19 PERSON
# millions CARDINAL
# Healthcare ORG
# one CARDINAL
# COVID-19 PERSON
# WHO ORG
# COVID-19 PRODUCT
# WHO ORG
# COVID-19 PERSON
# COVID-19 PERSON
# the next month DATE
# COVID19 ORG
# COVID-19 PERSON
# 16 CARDINAL
# COVID-19 PERSON
# 1 CARDINAL
# 2 CARDINAL
# 3 CARDINAL
# 4 CARDINAL
# TB ORG
#               Text     label
# 0          Malaria       GPE
# 1         COVID-19    PERSON
# 2         millions  CARDINAL
# 3       Healthcare       ORG
# 4              one  CARDINAL
# 5         COVID-19    PERSON
# 6              WHO       ORG
# 7         COVID-19   PRODUCT
# 8              WHO       ORG
# 9         COVID-19    PERSON
# 10        COVID-19    PERSON
# 11  the next month      DATE
# 12        COVID19       ORG
# 13        COVID-19    PERSON
# 14              16  CARDINAL
# 15        COVID-19    PERSON
# 16               1  CARDINAL
# 17               2  CARDINAL
# 18               3  CARDINAL
# 19               4  CARDINAL
# 20              TB       ORG

# %%
from spacy import displacy

# %%
nlp = spacy.load("en_core_web_sm")
doc = nlp(txt)
displacy.render(doc, style="ent")
# Out:
# <span class="tex2jax_ignore"><div class="entities" style="line-height: 2.5; direction: ltr">
# <mark class="entity" style="background: #feca74; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Malaria
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">GPE</span>
# </mark>
#  and
# <mark class="entity" style="background: #aa9cfc; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     COVID-19
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">PERSON</span>
# </mark>
#  may have similar aspects and seem to have a strong </br>potential for mutual influence. They have already caused
# <mark class="entity" style="background: #e4e7d2; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     millions
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">CARDINAL</span>
# </mark>
#  of deaths, </br>and the regions where malaria is endemic regions are at risk of suffering from </br>the consequences of COVID-19 due to mutual side effects, such as less access </br>to treatment for patients with malaria due to the fear of access to healthcare </br>centers leading to worse outcomes and diagnostic delays. </br> Moreover, the similar and generic symptoms make it harder to achieve an </br>immediate diagnosis.
# <mark class="entity" style="background: #7aecec; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Healthcare
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">ORG</span>
# </mark>
#  systems and professionals will face a great </br>challenge in case of a syndemic. Here, we present an overview of common and </br>different findings for both diseases with possible mutual influences of
# <mark class="entity" style="background: #e4e7d2; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     one
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">CARDINAL</span>
# </mark>
#  on </br>the other, especially in countries with limited resources. The role of young </br>health professionals, well-motivated and trained in primary care, will also be </br>essential in countries with a high burden of malaria. In patients with symptoms </br>such as fever, fatigue, and headache, both malaria and
# <mark class="entity" style="background: #aa9cfc; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     COVID-19
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">PERSON</span>
# </mark>
#  tests should </br>always be performed. According to recent
# <mark class="entity" style="background: #7aecec; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     WHO
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">ORG</span>
# </mark>
#  recommendations , in the case </br>of challenges due to the
# <mark class="entity" style="background: #bfeeb7; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     COVID-19
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">PRODUCT</span>
# </mark>
#  pandemic (e.g., supply chain disruption for </br>RDTs, health worker absenteeism, shortage of personal protective equipment) </br>a malaria diagnosis should be considered for all fever cases in endemic </br>countries. On the other hand, patients with COVID-19-related symptoms that </br>negative for malaria must undergo isolation to exclude COVID-19 until </br>repetition of the virological sample, thus reducing the potential risk of </br>transmission. Even though a COVID-19 outbreak may not occur in the malariaendemic regions, the
# <mark class="entity" style="background: #7aecec; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     WHO
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">ORG</span>
# </mark>
#  has called for ministries of health and national </br>malaria control programs to ensure that malaria control efforts are not </br>disrupted while facing the COVID-19 response . Preparedness is the key to </br>tackling any public health crisis, and malaria-endemic countries need to be </br>prepared for the challenges
# <mark class="entity" style="background: #aa9cfc; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     COVID-19
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">PERSON</span>
# </mark>
#  could pose. </br> The impact of the epidemic on the health financing system as a whole is </br>considered. A polarization of economic resources happened with Ebola, and this </br>is also being observed with
# <mark class="entity" style="background: #aa9cfc; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     COVID-19
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">PERSON</span>
# </mark>
# . Therefore, in
# <mark class="entity" style="background: #bfe1d9; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     the next month
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">DATE</span>
# </mark>
# , it could </br>be possible to observe an important decrease in economic and human </br>resources for malaria control programs, with a real risk of reducing prevention. </br>This is turn may result in an increase in the numbers of cases, with a </br>consequent increase in morbidity and mortality. The characteristics of
# <mark class="entity" style="background: #7aecec; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     COVID19
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">ORG</span>
# </mark>
#  and the previous experiences of the Ebola epidemic indicate the need for </br>malaria-endemic countries to consider measures for preparation and </br>prevention, focusing on not only the threat of
# <mark class="entity" style="background: #aa9cfc; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     COVID-19
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">PERSON</span>
# </mark>
#  but also the possible </br>impact of other diseases, especially malaria [
# <mark class="entity" style="background: #e4e7d2; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     16
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">CARDINAL</span>
# </mark>
# ]. In order to face these possible </br>scenarios,
# <mark class="entity" style="background: #aa9cfc; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     COVID-19
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">PERSON</span>
# </mark>
#  preparedness and response in malaria-endemic countries </br>should be focused on the following:
# <mark class="entity" style="background: #e4e

# %%
#displacy.render(doc, style="dep" , jupyter=True)

# %%
from nltk.tokenize import sent_tokenize
sentences = sent_tokenize(txt)
L = print(sent_tokenize(txt))
# Out:
# ['Malaria and COVID-19 may have similar aspects and seem to have a strong \npotential for mutual influence.', 'They have already caused millions of deaths, \nand the regions where malaria is endemic regions are at risk of suffering from \nthe consequences of COVID-19 due to mutual side effects, such as less access \nto treatment for patients with malaria due to the fear of access to healthcare \ncenters leading to worse outcomes and diagnostic delays.', 'Moreover, the similar and generic symptoms make it harder to achieve an \nimmediate diagnosis.', 'Healthcare systems and professionals will face a great \nchallenge in case of a syndemic.', 'Here, we present an overview of common and \ndifferent findings for both diseases with possible mutual influences of one on \nthe other, especially in countries with limited resources.', 'The role of young \nhealth professionals, well-motivated and trained in primary care, will also be \nessential in countries with a high burden of malaria.', 'In patients with symptoms \nsuch as fever, fatigue, and headache, both malaria and COVID-19 tests should \nalways be performed.', 'According to recent WHO recommendations , in the case \nof challenges due to the COVID-19 pandemic (e.g., supply chain disruption for \nRDTs, health worker absenteeism, shortage of personal protective equipment) \na malaria diagnosis should be considered for all fever cases in endemic \ncountries.', 'On the other hand, patients with COVID-19-related symptoms that \nnegative for malaria must undergo isolation to exclude COVID-19 until \nrepetition of the virological sample, thus reducing the potential risk of \ntransmission.', 'Even though a COVID-19 outbreak may not occur in the malaria\x02endemic regions, the WHO has called for ministries of health and national \nmalaria control programs to ensure that malaria control efforts are not \ndisrupted while facing the COVID-19 response .', 'Preparedness is the key to \ntackling any public health crisis, and malaria-endemic countries need to be \nprepared for the challenges COVID-19 could pose.', 'The impact of the epidemic on the health financing system as a whole is \nconsidered.', 'A polarization of economic resources happened with Ebola, and this \nis also being observed with COVID-19.', 'Therefore, in the next month, it could \nbe possible to observe an important decrease in economic and human \nresources for malaria control programs, with a real risk of reducing prevention.', 'This is turn may result in an increase in the numbers of cases, with a \nconsequent increase in morbidity and mortality.', 'The characteristics of COVID\x0219 and the previous experiences of the Ebola epidemic indicate the need for \nmalaria-endemic countries to consider measures for preparation and \nprevention, focusing on not only the threat of COVID-19 but also the possible \nimpact of other diseases, especially malaria [16].', 'In order to face these possible \nscenarios, COVID-19 preparedness and response in malaria-endemic countries \nshould be focused on the following: 1.', 'Local staff management, including \nprotection, training, supervision, incentives, and rest shifts, should focus on all \nfactors that together can help to ease the fear of contagion, diminish the anger \nover the death of colleagues, and contain strikes and protests; 2.', 'Infection \nprevention and control measures should be applied for healthcare workers at \nthe hospital and peripheral levels, making sure to institute appropriate low\x02technology measures such as washing hands with sodium hypochlorite, \nsegregation of hospital waste, and proper application of the personal \nprotective equipment; 3.', 'Community engagement is crucial, as an effective \ncommunication campaign involving local leaders, indigenous associations, and \nmedia can compel the community to conform to the new behaviors (distancing, \nhand washing, stopping of traditional funeral rites, collaborating in contact \ntracing, etc.)', 'and therefore ...

# %%
from nltk.tokenize import word_tokenize
for word in sentences:
    token_sentences = word_tokenize(word)

# %%
token_sentences
# Out:
# ['Finally',
#  ',',
#  'from',
#  'a',
#  'global',
#  'perspective',
#  ',',
#  'it',
#  'is',
#  'necessary',
#  'to',
#  'increase',
#  'and',
#  'join',
#  'efforts',
#  'in',
#  'order',
#  'to',
#  'develop',
#  'an',
#  'effective',
#  'vaccine',
#  'and',
#  'it',
#  'make',
#  'available',
#  'for',
#  'everyone',
#  ',',
#  'as',
#  'this',
#  'would',
#  'be',
#  'the',
#  'most',
#  'effective',
#  'preventive',
#  'measure',
#  'for',
#  'both',
#  'disease']

# %%
for word in sentences:
    text = word_tokenize(word)
    pos_sentences = nltk.pos_tag(text)

# %%
pos_sentences
# Out:
# [('Finally', 'RB'),
#  (',', ','),
#  ('from', 'IN'),
#  ('a', 'DT'),
#  ('global', 'JJ'),
#  ('perspective', 'NN'),
#  (',', ','),
#  ('it', 'PRP'),
#  ('is', 'VBZ'),
#  ('necessary', 'JJ'),
#  ('to', 'TO'),
#  ('increase', 'VB'),
#  ('and', 'CC'),
#  ('join', 'VB'),
#  ('efforts', 'NNS'),
#  ('in', 'IN'),
#  ('order', 'NN'),
#  ('to', 'TO'),
#  ('develop', 'VB'),
#  ('an', 'DT'),
#  ('effective', 'JJ'),
#  ('vaccine', 'NN'),
#  ('and', 'CC'),
#  ('it', 'PRP'),
#  ('make', 'VBP'),
#  ('available', 'JJ'),
#  ('for', 'IN'),
#  ('everyone', 'NN'),
#  (',', ','),
#  ('as', 'IN'),
#  ('this', 'DT'),
#  ('would', 'MD'),
#  ('be', 'VB'),
#  ('the', 'DT'),
#  ('most', 'RBS'),
#  ('effective', 'JJ'),
#  ('preventive', 'JJ'),
#  ('measure', 'NN'),
#  ('for', 'IN'),
#  ('both', 'DT'),
#  ('disease', 'NN')]

# %%
for i in sentences:
    doc = nlp(i)
    displacy.render(doc, style="dep" , jupyter=True)
# Out:
# <span class="tex2jax_ignore"><svg xmlns="http://www.w3.org/2000/svg" xmlns:xlink="http://www.w3.org/1999/xlink" xml:lang="en" id="4f466b742e6f4a1c98ee7f1b5b0d39f5-0" class="displacy" width="3200" height="487.0" direction="ltr" style="max-width: none; height: 487.0px; color: #000000; background: #ffffff; font-family: Arial; direction: ltr">
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="397.0">
#     <tspan class="displacy-word" fill="currentColor" x="50">Malaria</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="50">PROPN</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="397.0">
#     <tspan class="displacy-word" fill="currentColor" x="225">and</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="225">CCONJ</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="397.0">
#     <tspan class="displacy-word" fill="currentColor" x="400">COVID-19</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="400">NOUN</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="397.0">
#     <tspan class="displacy-word" fill="currentColor" x="575">may</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="575">AUX</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="397.0">
#     <tspan class="displacy-word" fill="currentColor" x="750">have</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="750">VERB</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="397.0">
#     <tspan class="displacy-word" fill="currentColor" x="925">similar</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="925">ADJ</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="397.0">
#     <tspan class="displacy-word" fill="currentColor" x="1100">aspects</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="1100">NOUN</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="397.0">
#     <tspan class="displacy-word" fill="currentColor" x="1275">and</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="1275">CCONJ</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="397.0">
#     <tspan class="displacy-word" fill="currentColor" x="1450">seem</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="1450">VERB</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="397.0">
#     <tspan class="displacy-word" fill="currentColor" x="1625">to</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="1625">PART</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="397.0">
#     <tspan class="displacy-word" fill="currentColor" x="1800">have</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="1800">VERB</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="397.0">
#     <tspan class="displacy-word" fill="currentColor" x="1975">a</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="1975">DET</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="397.0">
#     <tspan class="displacy-word" fill="currentColor" x="2150">strong</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="2150">ADJ</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="397.0">
#     <tspan class="displacy-word" fill="currentColor" x="2325">
# </tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="2325">SPACE</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="397.0">
#     <tspan class="displacy-word" fill="currentColor" x="2500">potential</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="2500">NOUN</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="397.0">
#     <tspan class="displacy-word" fill="currentColor" x="2675">for</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="2675">ADP</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="397.0">
#     <tspan class="displacy-word" fill="currentColor" x="2850">mutual</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="2850">ADJ</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="397.0">
#     <tspan class="displacy-word" fill="currentColor" x="3025">influence.</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="3025">NOUN</tspan>
# </text>
#
# <g class="displacy-arrow">
#     <path class="displacy-arc" id="arrow-4f466b742e6f4a1c98ee7f1b5b0d39f5-0-0" stroke-width="2px" d="M70,352.0 C70,2.0 750.0,2.0 750.0,352.0" fill="none" stroke="currentColor"/>
#     <text dy="1.25em" style="font-size: 0.8em; letter-spacing: 1px">
#         <textPath xlink:href="#arrow-4f466b742e6f4a1c98ee7f1b5b0d39f5-0-0" class="displacy-label" startOffset="50%" side="left" fill="currentColor" text-anchor="middle">nsubj</textPath>
#     </text>
#     <path class="displacy-arrowhead" d="M70,354.0 L62,342.0 78,342.0" fill="currentColor"/>
# </g>
#
# <g class="displacy-arrow">
#     <path class="displacy-arc" id="arrow-4f466b742e6f4a1c98ee7f1b5b0d39f5-0-1" stroke-width="2px" d="M70,352.0 C70,264.5 210.0,264.5 210.0,352.0" fill="none" stroke="currentColor"/>
#     <text dy="1.25em" style="font-size: 0.8em; letter-spacing: 1px">
#         <textPath xlink:href="#arrow-4f466b742e6f4a1c98ee7f1b5b0d39f5-0-1" class="displacy-label" startOffset="50%" side="left" fill="currentColor" text-anchor="middle">cc</textPath>
#     </text>
#     <path class="displacy-arrowhead" d="M210.0,354.0 L218.0,342.0 202.0,342.0" fill="currentColor"/>
# </g>
#
# <g class="displacy-arrow">
#     <path class="displacy-arc" id="arrow-4f466b742e6f4a1c98ee7f1b5b0d39f5-0-2" stroke-width="2px" d="M70,352.0 C70,177.0 390.0,177.0 390.0,352.0" fill="none" stroke="currentColor"/>
#     <text dy="1.25em" style="font-size: 0.8em; letter-spacing: 1px">
#         <textPath xlink:href="#arrow-4f466b742e6f4a1c98ee7f1b5b0d39f5-0-2" class="displacy-label" startOffset="50%" side="left" fill="currentColor" text-anchor="middle">conj</textPath>
#     </text>
#     <path class="displacy-arrowhead" d="M390.0,354.0 L398.0,342.0 382.0,342.0" fill="currentColor"/>
# </g>
#
# <g class="displacy-arrow">
#     <path class="displacy-arc" id="arrow-4f466b742e6f4a1c98ee7f1b5b0d39f5-0-3" stroke-width="2px" d="M595,352.0 C595,264.5 735.0,264.5 735.0,352.0" fill="none" stroke="currentColor"/>
#     <text dy="1.25em" style="font-size: 0.8em; letter-spacing: 1px">
#         <textPath xlink:href="#arrow-4f466b742e6f4a1c98ee7f1b5b0d39f5-0-3" class="displacy-label" startOffset="50%" side="left" fill="currentColor" text-anchor="middle">aux</textPath>
#     </text>
#     <path class="displacy-arrowhead" d="M595,354.0 L587,342.0 603,342.0" fill="currentColor"/>
# </g>
#
# <g class="displacy-arrow">
#     <path class="displacy-arc" id="arrow-4f466b742e6f4a1c98ee7f1b5b0d39f5-0-4" stroke-width="2px" d="M945,352.0 C945,264.5 1085.0,264.5 1085.0,352.0" fill="none" stroke="currentColor"/>
#     <text dy="1.25em" style="font-size: 0.8em; letter-spacing: 1px">
#         <textPath xlink:href="#arrow-4f466b742e6f4a1c98ee7f1b5b0d39f5-0-4" class="displacy-label" startOffset="50%" side="left" fill="currentColor" text-anchor="middle">amod</textPath>
#     </text>
#     <path class="displacy-arrowhead" d="M945,354.0 L937,342.0 953,342.0" fill="currentColor"/>
# </g>
#
# <g class="displacy-arrow">
#     <path class="displacy-arc" id="arrow-4f466b742e6f4a1c98ee7f1b5b0d39f5-0-5" stroke-width="2px" d="M770,352.0 C770,177.0 1090.0,177.0 1090.0,352.0" fill="none" stroke="currentColor"/>
#     <text dy="1.25em" style="font-size: 0.8em; letter-spacing: 1px">
#         <textPath xlink
# <span class="tex2jax_ignore"><svg xmlns="http://www.w3.org/2000/svg" xmlns:xlink="http://www.w3.org/1999/xlink" xml:lang="en" id="880e0747c61e401aa41c920a5471b405-0" class="displacy" width="10550" height="924.5" direction="ltr" style="max-width: none; height: 924.5px; color: #000000; background: #ffffff; font-family: Arial; direction: ltr">
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="834.5">
#     <tspan class="displacy-word" fill="currentColor" x="50">They</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="50">PRON</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="834.5">
#     <tspan class="displacy-word" fill="currentColor" x="225">have</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="225">AUX</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="834.5">
#     <tspan class="displacy-word" fill="currentColor" x="400">already</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="400">ADV</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="834.5">
#     <tspan class="displacy-word" fill="currentColor" x="575">caused</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="575">VERB</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="834.5">
#     <tspan class="displacy-word" fill="currentColor" x="750">millions</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="750">NOUN</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="834.5">
#     <tspan class="displacy-word" fill="currentColor" x="925">of</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="925">ADP</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="834.5">
#     <tspan class="displacy-word" fill="currentColor" x="1100">deaths,</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="1100">NOUN</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="834.5">
#     <tspan class="displacy-word" fill="currentColor" x="1275">
# </tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="1275">SPACE</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="834.5">
#     <tspan class="displacy-word" fill="currentColor" x="1450">and</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="1450">CCONJ</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="834.5">
#     <tspan class="displacy-word" fill="currentColor" x="1625">the</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="1625">DET</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="834.5">
#     <tspan class="displacy-word" fill="currentColor" x="1800">regions</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="1800">NOUN</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="834.5">
#     <tspan class="displacy-word" fill="currentColor" x="1975">where</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="1975">ADV</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="834.5">
#     <tspan class="displacy-word" fill="currentColor" x="2150">malaria</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="2150">NOUN</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="834.5">
#     <tspan class="displacy-word" fill="currentColor" x="2325">is</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="2325">VERB</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="834.5">
#     <tspan class="displacy-word" fill="currentColor" x="2500">endemic</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="2500">ADJ</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="834.5">
#     <tspan class="displacy-word" fill="currentColor" x="2675">regions</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="2675">NOUN</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="834.5">
#     <tspan class="displacy-word" fill="currentColor" x="2850">are</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="2850">VERB</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="834.5">
#     <tspan class="displacy-word" fill="currentColor" x="3025">at</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="3025">ADP</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="834.5">
#     <tspan class="displacy-word" fill="currentColor" x="3200">risk</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="3200">NOUN</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="834.5">
#     <tspan class="displacy-word" fill="currentColor" x="3375">of</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="3375">ADP</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="834.5">
#     <tspan class="displacy-word" fill="currentColor" x="3550">suffering</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="3550">VERB</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="834.5">
#     <tspan class="displacy-word" fill="currentColor" x="3725">from</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="3725">ADP</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="834.5">
#     <tspan class="displacy-word" fill="currentColor" x="3900">
# </tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="3900">SPACE</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="834.5">
#     <tspan class="displacy-word" fill="currentColor" x="4075">the</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="4075">DET</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="834.5">
#     <tspan class="displacy-word" fill="currentColor" x="4250">consequences</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="4250">NOUN</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="834.5">
#     <tspan class="displacy-word" fill="currentColor" x="4425">of</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="4425">ADP</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="834.5">
#     <tspan class="displacy-word" fill="currentColor" x="4600">COVID-19</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="4600">NOUN</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="834.5">
#     <tspan class="displacy-word" fill="currentColor" x="4775">due</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="4775">ADP</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="834.5">
#     <tspan class="displacy-word" fill="currentColor" x="4950">to</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="4950">ADP</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="834.5">
#     <tspan class="displacy-word" fill="currentColor" x="5125">mutual</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="5125">ADJ</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="834.5">
#     <tspan class="displacy-word" fill="currentColor" x="5300">side</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="5
# <span class="tex2jax_ignore"><svg xmlns="http://www.w3.org/2000/svg" xmlns:xlink="http://www.w3.org/1999/xlink" xml:lang="en" id="7d3adafe6cff48c0a9b16662b331296b-0" class="displacy" width="2675" height="574.5" direction="ltr" style="max-width: none; height: 574.5px; color: #000000; background: #ffffff; font-family: Arial; direction: ltr">
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="484.5">
#     <tspan class="displacy-word" fill="currentColor" x="50">Moreover,</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="50">ADV</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="484.5">
#     <tspan class="displacy-word" fill="currentColor" x="225">the</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="225">DET</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="484.5">
#     <tspan class="displacy-word" fill="currentColor" x="400">similar</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="400">ADJ</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="484.5">
#     <tspan class="displacy-word" fill="currentColor" x="575">and</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="575">CCONJ</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="484.5">
#     <tspan class="displacy-word" fill="currentColor" x="750">generic</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="750">ADJ</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="484.5">
#     <tspan class="displacy-word" fill="currentColor" x="925">symptoms</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="925">NOUN</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="484.5">
#     <tspan class="displacy-word" fill="currentColor" x="1100">make</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="1100">VERB</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="484.5">
#     <tspan class="displacy-word" fill="currentColor" x="1275">it</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="1275">PRON</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="484.5">
#     <tspan class="displacy-word" fill="currentColor" x="1450">harder</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="1450">ADJ</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="484.5">
#     <tspan class="displacy-word" fill="currentColor" x="1625">to</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="1625">PART</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="484.5">
#     <tspan class="displacy-word" fill="currentColor" x="1800">achieve</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="1800">VERB</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="484.5">
#     <tspan class="displacy-word" fill="currentColor" x="1975">an</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="1975">DET</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="484.5">
#     <tspan class="displacy-word" fill="currentColor" x="2150">
# </tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="2150">SPACE</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="484.5">
#     <tspan class="displacy-word" fill="currentColor" x="2325">immediate</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="2325">ADJ</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="484.5">
#     <tspan class="displacy-word" fill="currentColor" x="2500">diagnosis.</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="2500">NOUN</tspan>
# </text>
#
# <g class="displacy-arrow">
#     <path class="displacy-arc" id="arrow-7d3adafe6cff48c0a9b16662b331296b-0-0" stroke-width="2px" d="M70,439.5 C70,2.0 1100.0,2.0 1100.0,439.5" fill="none" stroke="currentColor"/>
#     <text dy="1.25em" style="font-size: 0.8em; letter-spacing: 1px">
#         <textPath xlink:href="#arrow-7d3adafe6cff48c0a9b16662b331296b-0-0" class="displacy-label" startOffset="50%" side="left" fill="currentColor" text-anchor="middle">advmod</textPath>
#     </text>
#     <path class="displacy-arrowhead" d="M70,441.5 L62,429.5 78,429.5" fill="currentColor"/>
# </g>
#
# <g class="displacy-arrow">
#     <path class="displacy-arc" id="arrow-7d3adafe6cff48c0a9b16662b331296b-0-1" stroke-width="2px" d="M245,439.5 C245,89.5 920.0,89.5 920.0,439.5" fill="none" stroke="currentColor"/>
#     <text dy="1.25em" style="font-size: 0.8em; letter-spacing: 1px">
#         <textPath xlink:href="#arrow-7d3adafe6cff48c0a9b16662b331296b-0-1" class="displacy-label" startOffset="50%" side="left" fill="currentColor" text-anchor="middle">det</textPath>
#     </text>
#     <path class="displacy-arrowhead" d="M245,441.5 L237,429.5 253,429.5" fill="currentColor"/>
# </g>
#
# <g class="displacy-arrow">
#     <path class="displacy-arc" id="arrow-7d3adafe6cff48c0a9b16662b331296b-0-2" stroke-width="2px" d="M420,439.5 C420,177.0 915.0,177.0 915.0,439.5" fill="none" stroke="currentColor"/>
#     <text dy="1.25em" style="font-size: 0.8em; letter-spacing: 1px">
#         <textPath xlink:href="#arrow-7d3adafe6cff48c0a9b16662b331296b-0-2" class="displacy-label" startOffset="50%" side="left" fill="currentColor" text-anchor="middle">amod</textPath>
#     </text>
#     <path class="displacy-arrowhead" d="M420,441.5 L412,429.5 428,429.5" fill="currentColor"/>
# </g>
#
# <g class="displacy-arrow">
#     <path class="displacy-arc" id="arrow-7d3adafe6cff48c0a9b16662b331296b-0-3" stroke-width="2px" d="M420,439.5 C420,352.0 555.0,352.0 555.0,439.5" fill="none" stroke="currentColor"/>
#     <text dy="1.25em" style="font-size: 0.8em; letter-spacing: 1px">
#         <textPath xlink:href="#arrow-7d3adafe6cff48c0a9b16662b331296b-0-3" class="displacy-label" startOffset="50%" side="left" fill="currentColor" text-anchor="middle">cc</textPath>
#     </text>
#     <path class="displacy-arrowhead" d="M555.0,441.5 L563.0,429.5 547.0,429.5" fill="currentColor"/>
# </g>
#
# <g class="displacy-arrow">
#     <path class="displacy-arc" id="arrow-7d3adafe6cff48c0a9b16662b331296b-0-4" stroke-width="2px" d="M420,439.5 C420,264.5 735.0,264.5 735.0,439.5" fill="none" stroke="currentColor"/>
#     <text dy="1.25em" style="font-size: 0.8em; letter-spacing: 1px">
#         <textPath xlink:href="#arrow-7d3adafe6cff48c0a9b16662b331296b-0-4" class="displacy-label" startOffset="50%" side="left" fill="currentColor" text-anchor="middle">conj</textPath>
#     </text>
#     <path class="displacy-arrowhead" d="M735.0,441.5 L743.0,429.5 727.0,429.5" fill="currentColor"/>
# </g>
#
# <g class="displacy-arrow">
#     <path class="displacy-arc" id="arrow-7d3adafe6cff48c0a9b16662b331296b-0-5" stroke-width="2px" d="M945,439.5 C945,352.0 1080.0,352.0 1080.0,439.5" fill="none" stroke="currentColor"/>
#     <text dy="1.25em" style="font-size: 0.8em; letter-spacing: 1px">
#         <textPath xlink:href="#arrow-7d3adafe6cff48c0a9b16662b331296b-0-5" class="displacy-label" startOffset="50%" side="left" fill="currentColor" text-anchor="middle">nsubj</textPath>
#     </text>
#     <path class="displacy-arrowhead" d="M945,441.5 L937,429.5 953,429.5" fill="currentColor"/>
# </g>
#
# <g class="displacy-arrow">
#     <path class="displacy-arc" id="arrow-7d3adafe6cff48c0a9b16662b331296b-0-6" stroke-width="2px" d="M1295,439.5 C1295,352.0 1430.0,352.0 1430.0,439.5" fill="none" stroke="currentColor"/>
#     <text dy="1.25em" style="font-size: 0.8em; letter-spacing: 1px">
#         <textPath xlink:href="#arrow-7d3adafe6cff48c0a9b16662b331296b-0-6" class="displacy-label" startOffset="50%" side="left" fill="currentColor" text-anchor="middle">nsubj</text
# <span class="tex2jax_ignore"><svg xmlns="http://www.w3.org/2000/svg" xmlns:xlink="http://www.w3.org/1999/xlink" xml:lang="en" id="cf5c18137ca1442da561af5d951bb53a-0" class="displacy" width="2675" height="574.5" direction="ltr" style="max-width: none; height: 574.5px; color: #000000; background: #ffffff; font-family: Arial; direction: ltr">
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="484.5">
#     <tspan class="displacy-word" fill="currentColor" x="50">Healthcare</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="50">NOUN</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="484.5">
#     <tspan class="displacy-word" fill="currentColor" x="225">systems</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="225">NOUN</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="484.5">
#     <tspan class="displacy-word" fill="currentColor" x="400">and</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="400">CCONJ</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="484.5">
#     <tspan class="displacy-word" fill="currentColor" x="575">professionals</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="575">NOUN</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="484.5">
#     <tspan class="displacy-word" fill="currentColor" x="750">will</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="750">AUX</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="484.5">
#     <tspan class="displacy-word" fill="currentColor" x="925">face</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="925">VERB</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="484.5">
#     <tspan class="displacy-word" fill="currentColor" x="1100">a</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="1100">DET</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="484.5">
#     <tspan class="displacy-word" fill="currentColor" x="1275">great</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="1275">ADJ</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="484.5">
#     <tspan class="displacy-word" fill="currentColor" x="1450">
# </tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="1450">SPACE</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="484.5">
#     <tspan class="displacy-word" fill="currentColor" x="1625">challenge</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="1625">NOUN</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="484.5">
#     <tspan class="displacy-word" fill="currentColor" x="1800">in</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="1800">ADP</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="484.5">
#     <tspan class="displacy-word" fill="currentColor" x="1975">case</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="1975">NOUN</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="484.5">
#     <tspan class="displacy-word" fill="currentColor" x="2150">of</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="2150">ADP</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="484.5">
#     <tspan class="displacy-word" fill="currentColor" x="2325">a</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="2325">DET</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="484.5">
#     <tspan class="displacy-word" fill="currentColor" x="2500">syndemic.</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="2500">NOUN</tspan>
# </text>
#
# <g class="displacy-arrow">
#     <path class="displacy-arc" id="arrow-cf5c18137ca1442da561af5d951bb53a-0-0" stroke-width="2px" d="M70,439.5 C70,352.0 205.0,352.0 205.0,439.5" fill="none" stroke="currentColor"/>
#     <text dy="1.25em" style="font-size: 0.8em; letter-spacing: 1px">
#         <textPath xlink:href="#arrow-cf5c18137ca1442da561af5d951bb53a-0-0" class="displacy-label" startOffset="50%" side="left" fill="currentColor" text-anchor="middle">compound</textPath>
#     </text>
#     <path class="displacy-arrowhead" d="M70,441.5 L62,429.5 78,429.5" fill="currentColor"/>
# </g>
#
# <g class="displacy-arrow">
#     <path class="displacy-arc" id="arrow-cf5c18137ca1442da561af5d951bb53a-0-1" stroke-width="2px" d="M245,439.5 C245,89.5 920.0,89.5 920.0,439.5" fill="none" stroke="currentColor"/>
#     <text dy="1.25em" style="font-size: 0.8em; letter-spacing: 1px">
#         <textPath xlink:href="#arrow-cf5c18137ca1442da561af5d951bb53a-0-1" class="displacy-label" startOffset="50%" side="left" fill="currentColor" text-anchor="middle">nsubj</textPath>
#     </text>
#     <path class="displacy-arrowhead" d="M245,441.5 L237,429.5 253,429.5" fill="currentColor"/>
# </g>
#
# <g class="displacy-arrow">
#     <path class="displacy-arc" id="arrow-cf5c18137ca1442da561af5d951bb53a-0-2" stroke-width="2px" d="M245,439.5 C245,352.0 380.0,352.0 380.0,439.5" fill="none" stroke="currentColor"/>
#     <text dy="1.25em" style="font-size: 0.8em; letter-spacing: 1px">
#         <textPath xlink:href="#arrow-cf5c18137ca1442da561af5d951bb53a-0-2" class="displacy-label" startOffset="50%" side="left" fill="currentColor" text-anchor="middle">cc</textPath>
#     </text>
#     <path class="displacy-arrowhead" d="M380.0,441.5 L388.0,429.5 372.0,429.5" fill="currentColor"/>
# </g>
#
# <g class="displacy-arrow">
#     <path class="displacy-arc" id="arrow-cf5c18137ca1442da561af5d951bb53a-0-3" stroke-width="2px" d="M245,439.5 C245,264.5 560.0,264.5 560.0,439.5" fill="none" stroke="currentColor"/>
#     <text dy="1.25em" style="font-size: 0.8em; letter-spacing: 1px">
#         <textPath xlink:href="#arrow-cf5c18137ca1442da561af5d951bb53a-0-3" class="displacy-label" startOffset="50%" side="left" fill="currentColor" text-anchor="middle">conj</textPath>
#     </text>
#     <path class="displacy-arrowhead" d="M560.0,441.5 L568.0,429.5 552.0,429.5" fill="currentColor"/>
# </g>
#
# <g class="displacy-arrow">
#     <path class="displacy-arc" id="arrow-cf5c18137ca1442da561af5d951bb53a-0-4" stroke-width="2px" d="M770,439.5 C770,352.0 905.0,352.0 905.0,439.5" fill="none" stroke="currentColor"/>
#     <text dy="1.25em" style="font-size: 0.8em; letter-spacing: 1px">
#         <textPath xlink:href="#arrow-cf5c18137ca1442da561af5d951bb53a-0-4" class="displacy-label" startOffset="50%" side="left" fill="currentColor" text-anchor="middle">aux</textPath>
#     </text>
#     <path class="displacy-arrowhead" d="M770,441.5 L762,429.5 778,429.5" fill="currentColor"/>
# </g>
#
# <g class="displacy-arrow">
#     <path class="displacy-arc" id="arrow-cf5c18137ca1442da561af5d951bb53a-0-5" stroke-width="2px" d="M1120,439.5 C1120,177.0 1615.0,177.0 1615.0,439.5" fill="none" stroke="currentColor"/>
#     <text dy="1.25em" style="font-size: 0.8em; letter-spacing: 1px">
#         <textPath xlink:href="#arrow-cf5c18137ca1442da561af5d951bb53a-0-5" class="displacy-label" startOffset="50%" side="left" fill="currentColor" text-anchor="middle">det</textPath>
#     </text>
#     <path class="displacy-arrowhead" d="M1120,441.5 L1112,429.5 1128,429.5" fill="currentColor"/>
# </g>
#
# <g class="displacy-arrow">
#     <path class="displacy-arc" id="arrow-cf5c18137ca1442da561af5d951bb53a-0-6" stroke-width="2px" d="M1295,439.5 C1295,264.5 1610.0,264.5 1610.0,439.5" fill="none" stroke="currentColor"/>
#     <text dy="1.25em" style="font-size: 0.8em; letter-spacing: 1px">
#         <textPath xlink:href="#arrow-cf5c18137ca1442da561af5d951bb53a-0-6" class="displacy-label" startOffset="50%" side="left" fill="currentColor" text-anchor="middle">amod</t
# <span class="tex2jax_ignore"><svg xmlns="http://www.w3.org/2000/svg" xmlns:xlink="http://www.w3.org/1999/xlink" xml:lang="en" id="44558c8b4259487583b8cafae9acfe65-0" class="displacy" width="5300" height="662.0" direction="ltr" style="max-width: none; height: 662.0px; color: #000000; background: #ffffff; font-family: Arial; direction: ltr">
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="572.0">
#     <tspan class="displacy-word" fill="currentColor" x="50">Here,</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="50">ADV</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="572.0">
#     <tspan class="displacy-word" fill="currentColor" x="225">we</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="225">PRON</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="572.0">
#     <tspan class="displacy-word" fill="currentColor" x="400">present</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="400">VERB</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="572.0">
#     <tspan class="displacy-word" fill="currentColor" x="575">an</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="575">DET</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="572.0">
#     <tspan class="displacy-word" fill="currentColor" x="750">overview</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="750">NOUN</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="572.0">
#     <tspan class="displacy-word" fill="currentColor" x="925">of</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="925">ADP</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="572.0">
#     <tspan class="displacy-word" fill="currentColor" x="1100">common</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="1100">ADJ</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="572.0">
#     <tspan class="displacy-word" fill="currentColor" x="1275">and</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="1275">CCONJ</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="572.0">
#     <tspan class="displacy-word" fill="currentColor" x="1450">
# </tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="1450">SPACE</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="572.0">
#     <tspan class="displacy-word" fill="currentColor" x="1625">different</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="1625">ADJ</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="572.0">
#     <tspan class="displacy-word" fill="currentColor" x="1800">findings</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="1800">NOUN</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="572.0">
#     <tspan class="displacy-word" fill="currentColor" x="1975">for</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="1975">ADP</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="572.0">
#     <tspan class="displacy-word" fill="currentColor" x="2150">both</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="2150">DET</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="572.0">
#     <tspan class="displacy-word" fill="currentColor" x="2325">diseases</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="2325">NOUN</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="572.0">
#     <tspan class="displacy-word" fill="currentColor" x="2500">with</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="2500">ADP</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="572.0">
#     <tspan class="displacy-word" fill="currentColor" x="2675">possible</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="2675">ADJ</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="572.0">
#     <tspan class="displacy-word" fill="currentColor" x="2850">mutual</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="2850">ADJ</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="572.0">
#     <tspan class="displacy-word" fill="currentColor" x="3025">influences</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="3025">NOUN</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="572.0">
#     <tspan class="displacy-word" fill="currentColor" x="3200">of</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="3200">ADP</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="572.0">
#     <tspan class="displacy-word" fill="currentColor" x="3375">one</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="3375">NUM</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="572.0">
#     <tspan class="displacy-word" fill="currentColor" x="3550">on</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="3550">ADP</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="572.0">
#     <tspan class="displacy-word" fill="currentColor" x="3725">
# </tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="3725">SPACE</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="572.0">
#     <tspan class="displacy-word" fill="currentColor" x="3900">the</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="3900">DET</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="572.0">
#     <tspan class="displacy-word" fill="currentColor" x="4075">other,</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="4075">ADJ</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="572.0">
#     <tspan class="displacy-word" fill="currentColor" x="4250">especially</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="4250">ADV</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="572.0">
#     <tspan class="displacy-word" fill="currentColor" x="4425">in</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="4425">ADP</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="572.0">
#     <tspan class="displacy-word" fill="currentColor" x="4600">countries</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="4600">NOUN</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="572.0">
#     <tspan class="displacy-word" fill="currentColor" x="4775">with</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="4775">ADP</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="572.0">
#     <tspan class="displacy-word" fill="currentColor" x="4950">limited</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="4950">ADJ</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="572.0">
#     <tspan class="displacy-word" fill="currentColor" x="5125">resources.</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="5125">NOUN</tspan>
# </text>
#
# <g class="displacy-arrow">
#     <path class="displacy-arc" id="arrow-44558c8b4259487583b8cafae9acfe65-0-0" stroke-width="2px" d="M70,527.0 C70,352.0 380.0,352.0 380.0,527.0" fill="none" stroke="currentColor"/>
# <span class="tex2jax_ignore"><svg xmlns="http://www.w3.org/2000/svg" xmlns:xlink="http://www.w3.org/1999/xlink" xml:lang="en" id="bd9c19da45c047bf8987a3acb46a187a-0" class="displacy" width="4775" height="574.5" direction="ltr" style="max-width: none; height: 574.5px; color: #000000; background: #ffffff; font-family: Arial; direction: ltr">
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="484.5">
#     <tspan class="displacy-word" fill="currentColor" x="50">The</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="50">DET</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="484.5">
#     <tspan class="displacy-word" fill="currentColor" x="225">role</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="225">NOUN</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="484.5">
#     <tspan class="displacy-word" fill="currentColor" x="400">of</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="400">ADP</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="484.5">
#     <tspan class="displacy-word" fill="currentColor" x="575">young</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="575">ADJ</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="484.5">
#     <tspan class="displacy-word" fill="currentColor" x="750">
# </tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="750">SPACE</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="484.5">
#     <tspan class="displacy-word" fill="currentColor" x="925">health</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="925">NOUN</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="484.5">
#     <tspan class="displacy-word" fill="currentColor" x="1100">professionals,</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="1100">NOUN</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="484.5">
#     <tspan class="displacy-word" fill="currentColor" x="1275">well-</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="1275">ADV</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="484.5">
#     <tspan class="displacy-word" fill="currentColor" x="1450">motivated</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="1450">VERB</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="484.5">
#     <tspan class="displacy-word" fill="currentColor" x="1625">and</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="1625">CCONJ</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="484.5">
#     <tspan class="displacy-word" fill="currentColor" x="1800">trained</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="1800">VERB</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="484.5">
#     <tspan class="displacy-word" fill="currentColor" x="1975">in</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="1975">ADP</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="484.5">
#     <tspan class="displacy-word" fill="currentColor" x="2150">primary</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="2150">ADJ</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="484.5">
#     <tspan class="displacy-word" fill="currentColor" x="2325">care,</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="2325">NOUN</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="484.5">
#     <tspan class="displacy-word" fill="currentColor" x="2500">will</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="2500">AUX</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="484.5">
#     <tspan class="displacy-word" fill="currentColor" x="2675">also</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="2675">ADV</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="484.5">
#     <tspan class="displacy-word" fill="currentColor" x="2850">be</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="2850">VERB</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="484.5">
#     <tspan class="displacy-word" fill="currentColor" x="3025">
# </tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="3025">SPACE</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="484.5">
#     <tspan class="displacy-word" fill="currentColor" x="3200">essential</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="3200">ADJ</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="484.5">
#     <tspan class="displacy-word" fill="currentColor" x="3375">in</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="3375">ADP</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="484.5">
#     <tspan class="displacy-word" fill="currentColor" x="3550">countries</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="3550">NOUN</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="484.5">
#     <tspan class="displacy-word" fill="currentColor" x="3725">with</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="3725">ADP</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="484.5">
#     <tspan class="displacy-word" fill="currentColor" x="3900">a</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="3900">DET</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="484.5">
#     <tspan class="displacy-word" fill="currentColor" x="4075">high</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="4075">ADJ</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="484.5">
#     <tspan class="displacy-word" fill="currentColor" x="4250">burden</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="4250">NOUN</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="484.5">
#     <tspan class="displacy-word" fill="currentColor" x="4425">of</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="4425">ADP</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="484.5">
#     <tspan class="displacy-word" fill="currentColor" x="4600">malaria.</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="4600">NOUN</tspan>
# </text>
#
# <g class="displacy-arrow">
#     <path class="displacy-arc" id="arrow-bd9c19da45c047bf8987a3acb46a187a-0-0" stroke-width="2px" d="M70,439.5 C70,352.0 205.0,352.0 205.0,439.5" fill="none" stroke="currentColor"/>
#     <text dy="1.25em" style="font-size: 0.8em; letter-spacing: 1px">
#         <textPath xlink:href="#arrow-bd9c19da45c047bf8987a3acb46a187a-0-0" class="displacy-label" startOffset="50%" side="left" fill="currentColor" text-anchor="middle">det</textPath>
#     </text>
#     <path class="displacy-arrowhead" d="M70,441.5 L62,429.5 78,429.5" fill="currentColor"/>
# </g>
#
# <g class="displacy-arrow">
#     <path class="displacy-arc" id="arrow-bd9c19da45c047bf8987a3acb46a187a-0-1" stroke-width="2px" d="M245,439.5 C245,2.0 2850.0,2.0 2850.0,439.5" fill="none" stroke="currentColor"/>
#     <text dy="1.25em" style="font-size: 0.8em; letter-spacing: 1px">
#         <textPath xlink:href="#arrow-bd9c19da45c047bf8987a3acb46a187a-0-1" class="displacy-label" startOffset="50%"
# ...
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="484.5">
#     <tspan class="displacy-word" fill="currentColor" x="50">It</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="50">PRON</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="484.5">
#     <tspan class="displacy-word" fill="currentColor" x="225">is</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="225">AUX</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="484.5">
#     <tspan class="displacy-word" fill="currentColor" x="400">of</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="400">ADP</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="484.5">
#     <tspan class="displacy-word" fill="currentColor" x="575">fundamental</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="575">ADJ</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="484.5">
#     <tspan class="displacy-word" fill="currentColor" x="750">importance</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="750">NOUN</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="484.5">
#     <tspan class="displacy-word" fill="currentColor" x="925">to</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="925">PART</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="484.5">
#     <tspan class="displacy-word" fill="currentColor" x="1100">monitor</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="1100">VERB</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="484.5">
#     <tspan class="displacy-word" fill="currentColor" x="1275">trends</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="1275">NOUN</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="484.5">
#     <tspan class="displacy-word" fill="currentColor" x="1450">of</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="1450">ADP</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="484.5">
#     <tspan class="displacy-word" fill="currentColor" x="1625">
# </tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="1625">SPACE</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="484.5">
#     <tspan class="displacy-word" fill="currentColor" x="1800">routine</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="1800">ADJ</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="484.5">
#     <tspan class="displacy-word" fill="currentColor" x="1975">health</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="1975">NOUN</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="484.5">
#     <tspan class="displacy-word" fill="currentColor" x="2150">services</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="2150">NOUN</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="484.5">
#     <tspan class="displacy-word" fill="currentColor" x="2325">use,</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="2325">NOUN</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="484.5">
#     <tspan class="displacy-word" fill="currentColor" x="2500">maternal</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="2500">ADJ</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="484.5">
#     <tspan class="displacy-word" fill="currentColor" x="2675">child</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="2675">NOUN</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="484.5">
#     <tspan class="displacy-word" fill="currentColor" x="2850">health,</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="2850">NOUN</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="484.5">
#     <tspan class="displacy-word" fill="currentColor" x="3025">TB,</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="3025">PROPN</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="484.5">
#     <tspan class="displacy-word" fill="currentColor" x="3200">HIV,</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="3200">PROPN</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="484.5">
#     <tspan class="displacy-word" fill="currentColor" x="3375">etc.</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="3375">X</tspan>
# </text>
#
# <g class="displacy-arrow">
#     <path class="displacy-arc" id="arrow-7c077c2bb4ef4df29c639bc745119c7f-0-0" stroke-width="2px" d="M70,439.5 C70,352.0 205.0,352.0 205.0,439.5" fill="none" stroke="currentColor"/>
#     <text dy="1.25em" style="font-size: 0.8em; letter-spacing: 1px">
#         <textPath xlink:href="#arrow-7c077c2bb4ef4df29c639bc745119c7f-0-0" class="displacy-label" startOffset="50%" side="left" fill="currentColor" text-anchor="middle">nsubj</textPath>
#     </text>
#     <path class="displacy-arrowhead" d="M70,441.5 L62,429.5 78,429.5" fill="currentColor"/>
# </g>
#
# <g class="displacy-arrow">
#     <path class="displacy-arc" id="arrow-7c077c2bb4ef4df29c639bc745119c7f-0-1" stroke-width="2px" d="M245,439.5 C245,352.0 380.0,352.0 380.0,439.5" fill="none" stroke="currentColor"/>
#     <text dy="1.25em" style="font-size: 0.8em; letter-spacing: 1px">
#         <textPath xlink:href="#arrow-7c077c2bb4ef4df29c639bc745119c7f-0-1" class="displacy-label" startOffset="50%" side="left" fill="currentColor" text-anchor="middle">prep</textPath>
#     </text>
#     <path class="displacy-arrowhead" d="M380.0,441.5 L388.0,429.5 372.0,429.5" fill="currentColor"/>
# </g>
#
# <g class="displacy-arrow">
#     <path class="displacy-arc" id="arrow-7c077c2bb4ef4df29c639bc745119c7f-0-2" stroke-width="2px" d="M595,439.5 C595,352.0 730.0,352.0 730.0,439.5" fill="none" stroke="currentColor"/>
#     <text dy="1.25em" style="font-size: 0.8em; letter-spacing: 1px">
#         <textPath xlink:href="#arrow-7c077c2bb4ef4df29c639bc745119c7f-0-2" class="displacy-label" startOffset="50%" side="left" fill="currentColor" text-anchor="middle">amod</textPath>
#     </text>
#     <path class="displacy-arrowhead" d="M595,441.5 L587,429.5 603,429.5" fill="currentColor"/>
# </g>
#
# <g class="displacy-arrow">
#     <path class="displacy-arc" id="arrow-7c077c2bb4ef4df29c639bc745119c7f-0-3" stroke-width="2px" d="M420,439.5 C420,264.5 735.0,264.5 735.0,439.5" fill="none" stroke="currentColor"/>
#     <text dy="1.25em" style="font-size: 0.8em; letter-spacing: 1px">
#         <textPath xlink:href="#arrow-7c077c2bb4ef4df29c639bc745119c7f-0-3" class="displacy-label" startOffset="50%" side="left" fill="currentColor" text-anchor="middle">pobj</textPath>
#     </text>
#     <path class="displacy-arrowhead" d="M735.0,441.5 L743.0,429.5 727.0,429.5" fill="currentColor"/>
# </g>
#
# <g class="displacy-arrow">
#     <path class="displacy-arc" id="arrow-7c077c2bb4ef4df29c639bc745119c7f-0-4" stroke-width="2px" d="M945,439.5 C945,352.0 1080.0,352.0 1080.0,439.5" fill="none" stroke="currentColor"/>
#     <text dy="1.25em" style="font-size: 0.8em; letter-spacing: 1px">
#         <textPath xlink:href="#arrow-7c077c2bb4ef4df29c639bc745119c7f-0-4" class="displacy-labe
# <span class="tex2jax_ignore"><svg xmlns="http://www.w3.org/2000/svg" xmlns:xlink="http://www.w3.org/1999/xlink" xml:lang="en" id="5766fcaed07d4f1c9b3bf64e1ffc05b3-0" class="displacy" width="7050" height="1012.0" direction="ltr" style="max-width: none; height: 1012.0px; color: #000000; background: #ffffff; font-family: Arial; direction: ltr">
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="922.0">
#     <tspan class="displacy-word" fill="currentColor" x="50">Finally,</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="50">ADV</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="922.0">
#     <tspan class="displacy-word" fill="currentColor" x="225">from</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="225">ADP</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="922.0">
#     <tspan class="displacy-word" fill="currentColor" x="400">a</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="400">DET</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="922.0">
#     <tspan class="displacy-word" fill="currentColor" x="575">global</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="575">ADJ</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="922.0">
#     <tspan class="displacy-word" fill="currentColor" x="750">perspective,</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="750">NOUN</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="922.0">
#     <tspan class="displacy-word" fill="currentColor" x="925">it</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="925">PRON</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="922.0">
#     <tspan class="displacy-word" fill="currentColor" x="1100">is</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="1100">AUX</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="922.0">
#     <tspan class="displacy-word" fill="currentColor" x="1275">necessary</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="1275">ADJ</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="922.0">
#     <tspan class="displacy-word" fill="currentColor" x="1450">to</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="1450">PART</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="922.0">
#     <tspan class="displacy-word" fill="currentColor" x="1625">increase</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="1625">VERB</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="922.0">
#     <tspan class="displacy-word" fill="currentColor" x="1800">and</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="1800">CCONJ</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="922.0">
#     <tspan class="displacy-word" fill="currentColor" x="1975">join</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="1975">VERB</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="922.0">
#     <tspan class="displacy-word" fill="currentColor" x="2150">efforts</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="2150">NOUN</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="922.0">
#     <tspan class="displacy-word" fill="currentColor" x="2325">
# </tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="2325">SPACE</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="922.0">
#     <tspan class="displacy-word" fill="currentColor" x="2500">in</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="2500">ADP</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="922.0">
#     <tspan class="displacy-word" fill="currentColor" x="2675">order</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="2675">NOUN</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="922.0">
#     <tspan class="displacy-word" fill="currentColor" x="2850">to</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="2850">PART</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="922.0">
#     <tspan class="displacy-word" fill="currentColor" x="3025">develop</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="3025">VERB</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="922.0">
#     <tspan class="displacy-word" fill="currentColor" x="3200">an</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="3200">DET</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="922.0">
#     <tspan class="displacy-word" fill="currentColor" x="3375">effective</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="3375">ADJ</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="922.0">
#     <tspan class="displacy-word" fill="currentColor" x="3550">vaccine</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="3550">NOUN</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="922.0">
#     <tspan class="displacy-word" fill="currentColor" x="3725">and</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="3725">CCONJ</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="922.0">
#     <tspan class="displacy-word" fill="currentColor" x="3900">it</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="3900">PRON</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="922.0">
#     <tspan class="displacy-word" fill="currentColor" x="4075">make</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="4075">VERB</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="922.0">
#     <tspan class="displacy-word" fill="currentColor" x="4250">available</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="4250">ADJ</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="922.0">
#     <tspan class="displacy-word" fill="currentColor" x="4425">for</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="4425">ADP</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="922.0">
#     <tspan class="displacy-word" fill="currentColor" x="4600">everyone,</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="4600">PRON</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="922.0">
#     <tspan class="displacy-word" fill="currentColor" x="4775">as</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="4775">ADP</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="922.0">
#     <tspan class="displacy-word" fill="currentColor" x="4950">
# </tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="4950">SPACE</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="922.0">
#     <tspan class="displacy-word" fill="currentColor" x="5125">this</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="5125">DET</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="922.0">
#     <tspan class="displacy-word" fill="currentColor" x="5300">would</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x

# %%
nlp = spacy.load('en_core_web_sm')

for i in sentences:
    doc = nlp(i)
    for token in doc:
        print(token.text, "-->", token.dep_)
# Out:
# Malaria --> nsubj
# and --> cc
# COVID-19 --> conj
# may --> aux
# have --> ROOT
# similar --> amod
# aspects --> dobj
# and --> cc
# seem --> conj
# to --> aux
# have --> xcomp
# a --> det
# strong --> amod
#
#  --> punct
# potential --> dobj
# for --> prep
# mutual --> amod
# influence --> pobj
# . --> punct
# They --> nsubj
# have --> aux
# already --> advmod
# caused --> ROOT
# millions --> dobj
# of --> prep
# deaths --> pobj
# , --> punct
#
#  --> punct
# and --> cc
# the --> det
# regions --> nsubj
# where --> advmod
# malaria --> nsubj
# is --> relcl
# endemic --> amod
# regions --> attr
# are --> conj
# at --> prep
# risk --> pobj
# of --> prep
# suffering --> pcomp
# from --> prep
#
#  --> punct
# the --> det
# consequences --> pobj
# of --> prep
# COVID-19 --> pobj
# due --> prep
# to --> pcomp
# mutual --> amod
# side --> compound
# effects --> pobj
# , --> punct
# such --> amod
# as --> prep
# less --> amod
# access --> pobj
#
#  --> punct
# to --> prep
# treatment --> pobj
# for --> prep
# patients --> pobj
# with --> prep
# malaria --> pobj
# due --> prep
# to --> pcomp
# the --> det
# fear --> pobj
# of --> prep
# access --> pobj
# to --> prep
# healthcare --> nmod
#
#  --> punct
# centers --> pobj
# leading --> acl
# to --> prep
# worse --> amod
# outcomes --> pobj
# and --> cc
# diagnostic --> amod
# delays --> conj
# . --> punct
# Moreover --> advmod
# , --> punct
# the --> det
# similar --> amod
# and --> cc
# generic --> conj
# symptoms --> nsubj
# make --> ROOT
# it --> nsubj
# harder --> ccomp
# to --> aux
# achieve --> advcl
# an --> det
#
#  --> nmod
# immediate --> amod
# diagnosis --> dobj
# . --> punct
# Healthcare --> compound
# systems --> nsubj
# and --> cc
# professionals --> conj
# will --> aux
# face --> ROOT
# a --> det
# great --> amod
#
#  --> compound
# challenge --> dobj
# in --> prep
# case --> pobj
# of --> prep
# a --> det
# syndemic --> pobj
# . --> punct
# Here --> advmod
# , --> punct
# we --> nsubj
# present --> ROOT
# an --> det
# overview --> dobj
# of --> prep
# common --> pobj
# and --> cc
#
#  --> conj
# different --> amod
# findings --> pobj
# for --> prep
# both --> det
# diseases --> pobj
# with --> prep
# possible --> amod
# mutual --> amod
# influences --> pobj
# of --> prep
# one --> pobj
# on --> prep
#
#  --> punct
# the --> det
# other --> pobj
# , --> punct
# especially --> advmod
# in --> prep
# countries --> pobj
# with --> prep
# limited --> amod
# resources --> pobj
# . --> punct
# The --> det
# role --> nsubj
# of --> prep
# young --> amod
#
#  --> compound
# health --> compound
# professionals --> pobj
# , --> punct
# well --> advmod
# - --> punct
# motivated --> amod
# and --> cc
# trained --> conj
# in --> prep
# primary --> amod
# care --> pobj
# , --> punct
# will --> aux
# also --> advmod
# be --> ROOT
#
#  --> punct
# essential --> acomp
# in --> prep
# countries --> pobj
# with --> prep
# a --> det
# high --> amod
# burden --> pobj
# of --> prep
# malaria --> pobj
# . --> punct
# In --> prep
# patients --> pobj
# with --> prep
# symptoms --> pobj
#
#  --> punct
# such --> amod
# as --> prep
# fever --> pobj
# , --> punct
# fatigue --> conj
# , --> punct
# and --> cc
# headache --> conj
# , --> punct
# both --> preconj
# malaria --> appos
# and --> cc
# COVID-19 --> conj
# tests --> conj
# should --> aux
#
#  --> intj
# always --> advmod
# be --> auxpass
# performed --> ROOT
# . --> punct
# According --> prep
# to --> prep
# recent --> amod
# WHO --> compound
# recommendations --> pobj
# , --> punct
# in --> nmod
# the --> det
# case --> pobj
#
#  --> punct
# of --> prep
# challenges --> pobj
# due --> amod
# to --> pcomp
# the --> det
# COVID-19 --> pobj
# pandemic --> amod
# ( --> punct
# e.g. --> advmod
# , --> punct
# supply --> compound
# chain --> compound
# disruption --> pobj
# for --> prep
#
#  --> compound
# RDTs --> pobj
# , --> punct
# health --> compound
# worker --> compound
# absenteeism --> conj
# , --> punct
# shortage --> pobj
# of --> prep
# personal --> amod
# protective --> amod
# equipment --> pobj
# ) --> punct
#
#  --> punct
# a --> det
# malaria --> amod
# diagnosis --> nsubjpass
# should --> aux
# be --> auxpass
# considered --> ROOT
# for --> prep
# all --> det
# fever --> compound
# cases --> pobj
# in --> prep
# endemic --> amod
#
#  --> compound
# countries --> pobj
# . --> punct
# On --> prep
# the --> det
# other --> amod
# hand --> pobj
# , --> punct
# patients --> ROOT
# with --> prep
# COVID-19 --> npadvmod
# - --> punct
# related --> amod
# symptoms --> pobj
# that --> nsubj
#
#  --> nsubj
# negative --> amod
# for --> prep
# malaria --> pobj
# must --> aux
# undergo --> relcl
# isolation --> dobj
# to --> aux
# exclude --> advcl
# COVID-19 --> dobj
# until --> prep
#
#  --> punct
# repetition --> pobj
# of --> prep
# the --> det
# virological --> amod
# sample --> pobj
# , --> punct
# thus --> advmod
# reducing --> acl
# the --> det
# potential --> amod
# risk --> dobj
# of --> prep
#
#  --> compound
# transmission --> pobj
# . --> punct
# Even --> advmod
# though --> mark
# a --> det
# COVID-19 --> compound
# outbreak --> nsubj
# may --> aux
# not --> neg
# occur --> advcl
# in --> prep
# the --> det
# malariaendemic --> amod
# regions --> pobj
# , --> punct
# the --> det
# WHO --> nsubj
# has --> aux
# called --> ROOT
# for --> prep
# ministries --> pobj
# of --> prep
# health --> pobj
# and --> cc
# national --> conj
#
#  --> compound
# malaria --> compound
# control --> compound
# programs --> dobj
# to --> aux
# ensure --> advcl
# that --> mark
# malaria --> compound
# control --> compound
# efforts --> nsubjpass
# are --> auxpass
# not --> neg
#
#  --> auxpass
# disrupted --> ccomp
# while --> mark
# facing --> advcl
# the --> det
# COVID-19 --> compound
# response --> dobj
# . --> punct
# Preparedness --> nsubj
# is --> ROOT
# the --> det
# key --> attr
# to --> prep
#
#  --> punct
# tackling --> pcomp
# any --> det
# public --> amod
# health --> compound
# crisis --> dobj
# , --> punct
# and --> cc
# malaria --> amod
# - --> punct
# endemic --> amod
# countries --> nsubj
# need --> conj
# to --> aux
# be --> xcomp
#
#  --> punct
# prepared --> acomp
# for --> mark
# the --> det
# challenges --> compound
# COVID-19 --> nsubj
# could --> aux
# pose --> ccomp
# . --> punct
# The --> det
# impact --> nsubjpass
# of --> prep
# the --> det
# epidemic --> pobj
# on --> prep
# the --> det
# health --> compound
# financing --> compound
# system --> pobj
# as --> prep
# a --> det
# whole --> pobj
# is --> auxpass
#
#  --> punct
# considered --> ROOT
# . --> punct
# A --> det
# polarization --> nsubj
# of --> prep
# economic --> amod
# resources --> pobj
# happened --> ROOT
# with --> prep
# Ebola --> pobj
# , --> punct
# and --> cc
# this --> det
#
#  --> nsubjpass
# is --> aux
# also --> advmod
# being --> auxpass
# observed --> conj
# with --> prep
# COVID-19 --> pobj
# . --> punct
# Therefore --> advmod
# , --> punct
# in --> prep
# the --> det
# next --> amod
# month --> pobj
# , --> punct
# it --> nsubj
# could --> aux
#
#  --> intj
# be --> ROOT
# possible --> acomp
# to --> aux
# observe --> xcomp
# an --> det
# important --> amod
# decrease --> dobj
# in --> prep
# economic --> amod
# and --> cc
# human --> conj
#
#  --> compound
# resources --> pobj
# for --> prep
# malaria --> compound
# control --> compound
# programs --> pobj
# , --> punct
# with --> prep
# a --> det
# real --> amod
# risk --> pobj
# of --> prep
# reducing --> pcomp
# prevention --> dobj
# . --> punct
# This --> nsubj
# is --> csubj
# turn --> attr
# may --> aux
# result --> ROOT
# in --> prep
# an --> det
# increase --> pobj
# in --> prep
# the --> det
# numbers --> pobj
# of --> prep
# cases --> pobj
# , --> punct
# with --> prep
# a --> det
#
#  --> nmod
# consequent --> amod
# increase --> pobj
# in --> prep
# morbidity --> pobj
# and --> cc
# mortality --> conj
# . --> punct
# The --> det
# characteristics --> nsubj
# of --> prep
# COVID19 --> pobj
# and --> cc
# the --> det
# previous --> amod
# experiences --> conj
# of --> prep
# the --> det
# Ebola --> compound
# epidemic --> pobj
# indicate --> ROOT
# the --> det
# need --> dobj
# for --> prep
#
#  --> punct
# malaria --> amod
# - --> punct
# endemic --> amod
# countries --> pobj
# to --> aux
# consider --> relcl
# measures --> dobj
# for --> prep
# preparation --> pobj
# and --> cc
#
#  --> conj
# prevention --> conj
# , --> punct
# focusing --> acl
# on --> prep
# not --> preconj
# only --> advmod
# the --> det
# threat --> pobj
# of --> prep
# COVID-19 --> pobj
# but --> cc
# also --> advmod
# the --> det
# possible --> amod
#
#  --> compound
# impact --> conj
# of --> prep
# other --> amod
# diseases --> pobj
# , --> punct
# especially --> advmod
# malaria --> appos
# [ --> punct
# 16 --> appos
# ] --> punct
# . --> punct
# In --> prep
# order --> pobj
# to --> aux
# face --> acl
# these --> det
# possible --> amod
#
#  --> punct
# scenarios --> dobj
# , --> punct
# COVID-19 --> compound
# preparedness --> conj
# and --> cc
# response --> conj
# in --> prep
# malaria --> amod
# - --> punct
# endemic --> amod
# countries --> pobj
#
#  --> nsubjpass
# should --> aux
# be --> auxpass
# focused --> ROOT
# on --> prep
# the --> det
# following --> pobj
# : --> punct
# 1 --> appos
# . --> punct
# Local --> amod
# staff --> compound
# management --> nsubj
# , --> punct
# including --> prep
#
#  --> compound
# protection --> pobj
# , --> punct
# training --> conj
# , --> punct
# supervision --> conj
# , --> punct
# incentives --> conj
# , --> punct
# and --> cc
# rest --> compound
# shifts --> conj
# , --> punct
# should --> aux
# focus --> ROOT
# on --> prep
# all --> det
#
#  --> compound
# factors --> pobj
# that --> nsubj
# together --> advmod
# can --> aux
# help --> relcl
# to --> aux
# ease --> xcomp
# the --> det
# fear --> dobj
# of --> prep
# contagion --> pobj
# , --> punct
# diminish --> conj
# the --> det
# anger --> dobj
#
#  --> punct
# over --> prep
# the --> det
# death --> pobj
# of --> prep
# colleagues --> pobj
# , --> punct
# and --> cc
# contain --> conj
# strikes --> dobj
# and --> cc
# protests --> conj
# ; --> punct
# 2 --> dep
# . --> punct
# Infection --> nmod
#
#  --> punct
# prevention --> nmod
# and --> cc
# control --> conj
# measures --> nsubjpass
# should --> aux
# be --> auxpass
# applied --> ROOT
# for --> prep
# healthcare --> compound
# workers --> pobj
# at --> prep
#
#  --> punct
# the --> det
# hospital --> nmod
# and --> cc
# peripheral --> conj
# levels --> pobj
# , --> punct
# making --> advcl
# sure --> acomp
# to --> aux
# institute --> xcomp
# appropriate --> amod
# lowtechnology --> compound
# measures --> dobj
# such --> amod
# as --> prep
# washing --> pcomp
# hands --> dobj
# with --> prep
# sodium --> compound
# hypochlorite --> pobj
# , --> punct
#
#  --> compound
# segregation --> npadvmod
# of --> prep
# hospital --> compound
# waste --> pobj
# , --> punct
# and --> cc
# proper --> amod
# application --> conj
# of --> prep
# the --> det
# personal --> amod
#
#  --> nmod
# protective --> amod
# equipment --> pobj
# ; --> punct
# 3 --> appos
# . --> punct
# Community --> compound
# engagement --> nsubj
# is --> ROOT
# crucial --> acomp
# , --> punct
# as --> prep
# an --> det
# effective --> amod
#
#  --> compound
# communication --> compound
# campaign --> pobj
# involving --> acl
# local --> amod
# leaders --> dobj
# , --> punct
# indigenous --> amod
# associations --> conj
# , --> punct
# and --> cc
#
#  --> compound
# media --> conj
# can --> aux
# compel --> advcl
# the --> det
# community --> dobj
# to --> aux
# conform --> xcomp
# to --> prep
# the --> det
# new --> amod
# behaviors --> pobj
# ( --> punct
# distancing --> appos
# , --> punct
#
#  --> punct
# hand --> compound
# washing --> dobj
# , --> punct
# stopping --> conj
# of --> prep
# traditional --> amod
# funeral --> compound
# rites --> pobj
# , --> punct
# collaborating --> advcl
# in --> prep
# contact --> nmod
#
#  --> punct
# tracing --> pobj
# , --> punct
# etc --> conj
# . --> punct
# ) --> punct
# and --> cc
# therefore --> advmod
# in --> prep
# the --> det
# end --> pobj
# be --> ROOT
# able --> acomp
# to --> aux
# retain --> xcomp
# trust --> dobj
# in --> prep
# healthcare --> nmod
#
#  --> punct
# structures --> pobj
# and --> cc
# operators --> conj
# ; --> punct
# 4 --> npadvmod
# . --> punct
# Data --> compound
# management --> nsubjpass
# and --> cc
# operational --> amod
# research --> conj
#
#  --> punct
# should --> aux
# not --> neg
# be --> auxpass
# neglected --> ROOT
# . --> punct
# It --> nsubj
# is --> ROOT
# of --> prep
# fundamental --> amod
# importance --> pobj
# to --> aux
# monitor --> xcomp
# trends --> dobj
# of --> prep
#
#  --> nmod
# routine --> amod
# health --> compound
# services --> compound
# use --> pobj
# , --> punct
# maternal --> amod
# child --> compound
# health --> conj
# , --> punct
# TB --> conj
# , --> punct
# HIV --> conj
# , --> punct
# etc --> conj
# . --> punct
# Finally --> advmod
# , --> punct
# from --> prep
# a --> det
# global --> amod
# perspective --> pobj
# , --> punct
# it --> nsubj
# is --> ROOT
# necessary --> acomp
# to --> aux
# increase --> xcomp
# and --> cc
# join --> conj
# efforts --> dobj
#
#  --> punct
# in --> prep
# order --> pobj
# to --> aux
# develop --> acl
# an --> det
# effective --> amod
# vaccine --> dobj
# and --> cc
# it --> nsubj
# make --> conj
# available --> acomp
# for --> prep
# everyone --> pobj
# , --> punct
# as --> mark
#
#  --> punct
# this --> nsubj
# would --> aux
# be --> advcl
# the --> det
# most --> advmod
# effective --> amod
# preventive --> amod
# measure --> attr
# for --> prep
# both --> det
# disease --> pobj

# %%
# Relation extraction

# %%
from spacy.matcher import Matcher 
from tqdm import tqdm

# %%
def get_entities(sent):
  ent1 = ""
  ent2 = ""

  prv_tok_dep = ""    
  prv_tok_text = ""  

  prefix = ""
  modifier = ""
  
  for tok in nlp(sent):
    if tok.dep_ != "punct":
      if tok.dep_ == "compound":
        prefix = tok.text
        if prv_tok_dep == "compound":
          prefix = prv_tok_text + " "+ tok.text
      
      if tok.dep_.endswith("mod") == True:
        modifier = tok.text
        if prv_tok_dep == "compound":
          modifier = prv_tok_text + " "+ tok.text
      
      if tok.dep_.find("subj") == True:
        ent1 = modifier +" "+ prefix + " "+ tok.text
        prefix = ""
        modifier = ""
        prv_tok_dep = ""
        prv_tok_text = ""      

      if tok.dep_.find("obj") == True:
        ent2 = modifier +" "+ prefix +" "+ tok.text
        

      prv_tok_dep = tok.dep_
      prv_tok_text = tok.text

  return [ent1.strip(), ent2.strip()]

# %%
for i in sentences:
    print(get_entities(i))
# Out:
# ['Malaria', 'mutual  influence']
# ['where  malaria', 'worse side outcomes']
# ['it', 'immediate  diagnosis']
# ['Healthcare systems', 'great \n syndemic']
# ['Here  we', 'limited  resources']
# ['role', 'high \n health malaria']
# ['', 'such  fever']
# ['malaria health worker diagnosis', 'endemic \n countries']
# ['', 'potential \n transmission']
# ['malaria control efforts', 'COVID-19 response']
# ['challenges COVID-19', 'public health crisis']
# ['impact', 'health financing whole']
# ['economic', 'also  COVID-19']
# ['next  it', 'real malaria control prevention']
# ['is', 'consequent  morbidity']
# ['characteristics', 'other \n diseases']
# ['endemic COVID-19', 'following']
# ['that', 'together  strikes']
# ['prevention  measures', 'protective hospital equipment']
# ['Community engagement', 'contact funeral tracing']
# ['', 'healthcare  structures']
# ['Data management', '']
# ['It', 'routine health services use']
# ['this', 'preventive  disease']

# %%
entity_pairs = []

for i in tqdm(sentences):
  entity_pairs.append(get_entities(i))
# Out:
# 100%|██████████| 24/24 [00:00<00:00, 108.89it/s]

# %%
entity_pairs[10:20]
# Out:
# [['challenges COVID-19', 'public health crisis'],
#  ['impact', 'health financing whole'],
#  ['economic', 'also  COVID-19'],
#  ['next  it', 'real malaria control prevention'],
#  ['is', 'consequent  morbidity'],
#  ['characteristics', 'other \n diseases'],
#  ['endemic COVID-19', 'following'],
#  ['that', 'together  strikes'],
#  ['prevention  measures', 'protective hospital equipment'],
#  ['Community engagement', 'contact funeral tracing']]

# %%
def get_relation(sent):

  doc = nlp(sent)

  # Matcher class object 
  matcher = Matcher(nlp.vocab)

  #define the pattern 
  pattern = [{'DEP':'ROOT'}, 
            {'DEP':'prep','OP':"?"},
            {'DEP':'agent','OP':"?"},  
            {'POS':'ADJ','OP':"?"}] 

  matcher.add('matching_1', [pattern]) 

  matches = matcher(doc)
  k = len(matches) - 1

  span = doc[matches[k][1]:matches[k][2]] 

  return(span.text)

# %%
relations = [get_relation(i) for i in tqdm(sentences)]
# Out:
# 100%|██████████| 24/24 [00:00<00:00, 114.59it/s]

# %%
pd.Series(relations).value_counts()[:50]
# Out:
# have similar         1
# caused               1
# is of fundamental    1
# neglected            1
# be able              1
# is crucial           1
# applied for          1
# focus on             1
# focused on           1
# indicate             1
# result in            1
# be possible          1
# happened with        1
# considered           1
# is                   1
# called for           1
# patients with        1
# considered for       1
# performed            1
# be                   1
# present              1
# face                 1
# make                 1
# is necessary         1
# dtype: int64

# %%
# Knowledge Graph Extraction

# %%
import networkx as nx
import matplotlib.pyplot as plt

# %%
source = [i[0] for i in entity_pairs]

target = [i[1] for i in entity_pairs]

kg_df = pd.DataFrame({'source':source, 'target':target, 'edge':relations})

# %%
G=nx.from_pandas_edgelist(kg_df, "source", "target", edge_attr=True, create_using=nx.MultiDiGraph())

# %%
plt.figure(figsize=(30,30))
pos = nx.spring_layout(G)
nx.draw(G, with_labels=True, node_color='skyblue', edge_cmap=plt.cm.Blues, pos = pos)
plt.show()

# %%
G=nx.from_pandas_edgelist(kg_df[kg_df['edge']=="caused"], "source", "target", edge_attr=True, create_using=nx.MultiDiGraph())
plt.figure(figsize=(30,30))
pos = nx.spring_layout(G, k = 0.5) 
nx.draw(G, with_labels=True, node_color='skyblue', node_size=1500, edge_cmap=plt.cm.Blues, pos = pos)
plt.show()

# %%
entity_pairs1 = []
relations1 = []

for i in tqdm(sentences):
    entity_pairs1.append(get_entities(i))
    relations1.append(get_relation(i))
    source = entity_pairs1[0][0]
    target = entity_pairs1[0][1]
    kg1_df = pd.DataFrame({'source':source, 'target':target, 'edge':relations1})
    G1=nx.from_pandas_edgelist(kg1_df, "source", "target", edge_attr=True, create_using=nx.MultiDiGraph())
    plt.figure(figsize=(15,15))
    pos = nx.spring_layout(G)
    nx.draw(G1, with_labels=True, node_color='skyblue', edge_cmap=plt.cm.Blues)
    plt.show()
    entity_pairs1 = []
    relations1 = []
# Out:
#   0%|          | 0/24 [00:00<?, ?it/s]
#   4%|▍         | 1/24 [00:00<00:03,  6.55it/s]
#   8%|▊         | 2/24 [00:00<00:04,  4.94it/s]
#  12%|█▎        | 3/24 [00:00<00:03,  5.42it/s]
#  17%|█▋        | 4/24 [00:00<00:03,  5.75it/s]
#  21%|██        | 5/24 [00:00<00:03,  6.01it/s]
#  25%|██▌       | 6/24 [00:01<00:02,  6.22it/s]
#  29%|██▉       | 7/24 [00:01<00:02,  6.34it/s]
#  33%|███▎      | 8/24 [00:01<00:02,  6.40it/s]
#  38%|███▊      | 9/24 [00:01<00:02,  6.26it/s]
#  42%|████▏     | 10/24 [00:01<00:02,  6.36it/s]
#  46%|████▌     | 11/24 [00:01<00:02,  6.49it/s]
#  50%|█████     | 12/24 [00:01<00:01,  6.65it/s]
#  54%|█████▍    | 13/24 [00:02<00:01,  6.74it/s]
#  58%|█████▊    | 14/24 [00:02<00:01,  6.74it/s]
#  62%|██████▎   | 15/24 [00:02<00:01,  6.82it/s]
#  67%|██████▋   | 16/24 [00:02<00:01,  6.78it/s]
#  71%|███████   | 17/24 [00:02<00:01,  6.49it/s]
#  75%|███████▌  | 18/24 [00:02<00:00,  6.54it/s]
#  79%|███████▉  | 19/24 [00:03<00:00,  6.50it/s]
#  83%|████████▎ | 20/24 [00:03<00:00,  6.53it/s]
#  88%|████████▊ | 21/24 [00:03<00:00,  6.65it/s]
#  92%|█████████▏| 22/24 [00:03<00:00,  6.82it/s]
#  96%|█████████▌| 23/24 [00:03<00:00,  6.82it/s]
# 100%|██████████| 24/24 [00:03<00:00,  6.34it/s]
